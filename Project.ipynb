Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:28  260429_LI_.00000235.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:30  260429_LI_.00000236.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:31  260429_LI_.00000237.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:33  260429_LI_.00000238.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:34  260429_LI_.00000239.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:35  260429_LI_.00000240.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:37  260429_LI_.00000241.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:38  260429_LI_.00000242.Mouse_click_position.BLUE.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:40  260429_LI_.00000243.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:40  260429_LI_.00000244.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:40  260429_LI_.00000245.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:41  260429_LI_.00000246.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:41  260429_LI_.00000247.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:41  260429_LI_.00000248.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:42  260429_LI_.00000249.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:42  260429_LI_.00000250.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:43  260429_LI_.00000251.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:43  260429_LI_.00000252.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:43  260429_LI_.00000253.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:44  260429_LI_.00000254.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:44  260429_LI_.00000255.Mouse_click_position.BIAS.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:47  260429_LI_.00000257.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:48  260429_LI_.00000258.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:48  260429_LI_.00000259.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:49  260429_LI_.00000260.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:49  260429_LI_.00000261.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:53  260429_LI_.00000262.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:54  260429_LI_.00000263.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:55  260429_LI_.00000264.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:57  260429_LI_.00000265.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 04:58  260429_LI_.00000266.Mouse_click_position.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:07  260429_LI_.00000269.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:08  260429_LI_.00000270.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:10  260429_LI_.00000271.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:10  260429_LI_.00000272.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:11  260429_LI_.00000273.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:11  260429_LI_.00000274.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:40  260429_LI_.00000275.M_52.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:40  260429_LI_.00000276.00h04m59.7s_40d49m25sN.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:41  260429_LI_.00000277.00h05m07.7s_40d49m51sN.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:41  260429_LI_.00000278.00h05m13.7s_40d50m16sN.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:44  260429_LI_.00000279.00h05m13.7s_40d50m16sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:45  260429_LI_.00000280.00h05m18.7s_40d50m42sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:45  260429_LI_.00000281.00h05m27.7s_40d51m08sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:46  260429_LI_.00000282.00h05m27.7s_40d51m08sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:46  260429_LI_.00000283.00h05m30.7s_40d51m34sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer 12591360 Apr 30 05:47  260429_LI_.00000284.00h05m41.6s_40d52m00sN.FLAT.FIT
# -rw-r--r-- 1 telescoop observer        0 Apr 29 20:09 'Select Folder.~~~'

# %%
import os
import shutil
import glob

# paths
src = '/net/vega/data/users/observatory/images/260429/STL-6303E/i/'
dst = '/net/virgo01/data/users/ahayr/meine_beobachtungen/'

if not os.path.exists(dst):
    os.makedirs(dst)

files = glob.glob(os.path.join(src, '*.FIT'))

# fallback if extensions are lowercase
if not files:
    files = [os.path.join(src, f) for f in os.listdir(src) if f.lower().endswith(('.fit', '.fits'))]

print(f"found {len(files)} files, copying...")

for p in files:
    name = os.path.basename(p)
    
    # skip that weird 'Select Folder' file
    if "Select Folder" in name:
        continue
        
    shutil.copy(p, os.path.join(dst, name))

print("done.")
print(os.listdir(dst)[:5])
# Out:
# found 280 files, copying...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 27
#      24     if "Select Folder" in name:
#      25         continue
# ---> 27     shutil.copy(p, os.path.join(dst, name))
#      29 print("done.")
#      30 print(os.listdir(dst)[:5])
#
# File /opt/anaconda-hub/lib/python3.13/shutil.py:428, in copy(src, dst, follow_symlinks)
#     426 if os.path.isdir(dst):
#     427     dst = os.path.join(dst, os.path.basename(src))
# --> 428 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429 copymode(src, dst, follow_symlinks=follow_symlinks)
#     430 return dst
#
# File /opt/anaconda-hub/lib/python3.13/shutil.py:262, in copyfile(src, dst, follow_symlinks)
#     260 with open(src, 'rb') as fsrc:
#     261     try:
# --> 262         with open(dst, 'wb') as fdst:
#     263             # macOS
#     264             if _HAS_FCOPYFILE:
#     265                 try:
#
# PermissionError: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/260429_LI_.00000186.23h24m52.3s_61d34m35sN.BLUE.FIT'

# %%
import os
import re
import pandas as pd
from astropy.io import fits

dst = '/net/virgo01/data/users/ahayr/meine_beobachtungen/'
data = []

for f in sorted(os.listdir(dst)):
    if f.lower().endswith(('.fit', '.fits')):
        
        match = re.search(r'\.(\d{8})\.', f)
        if match:
            num = int(match.group(1))
            if num < 145:
                continue
        else:
            continue
            
        full_path = os.path.join(dst, f)
        try:
            with fits.open(full_path) as hdul:
                hdr = hdul[0].header
                if (num > 256) and (num < 267):
                    hdr["IMAGETYP"] = "Dark Frame"
                data.append({
                    'filename': f,
                    'object': hdr.get('OBJECT', 'N/A'),
                    'type': hdr.get('IMAGETYP', 'N/A'),
                    'exptime': hdr.get('EXPTIME', 'N/A'),
                    'filter': hdr.get('FILTER', 'N/A')
                })
        except Exception as e:
            print(f"err on {f}: {e}")

df = pd.DataFrame(data)

# extract file number to drop duplicates
df['tmp_num'] = df['filename'].str.extract(r'\.(\d{8})\.')
df = df.drop_duplicates(subset=['tmp_num']).drop(columns=['tmp_num'])

pd.set_option('display.max_rows', None)

print(f"done. unique rows: {len(df)}")
display(df)
# Out:
# done. unique rows: 136
#                                               filename                object  \
# 0       260429_LI_.00000145.23h24m52.3s_61d34m35sN.FIT                   N/A
# 1       260429_LI_.00000146.23h24m53.3s_61d34m35sN.FIT                   N/A
# 2       260429_LI_.00000148.23h24m53.3s_61d34m35sN.FIT                   N/A
# 3       260429_LI_.00000149.23h24m54.3s_61d34m35sN.FIT                   N/A
# 4       260429_LI_.00000150.23h24m53.3s_61d34m35sN.FIT                   N/A
# 5       260429_LI_.00000151.23h24m53.3s_61d34m35sN.FIT                   N/A
# 6       260429_LI_.00000152.23h24m54.3s_61d34m35sN.FIT                   N/A
# 7       260429_LI_.00000153.23h24m52.3s_61d34m35sN.FIT                   N/A
# 8       260429_LI_.00000154.23h24m53.3s_61d34m35sN.FIT                   N/A
# 9       260429_LI_.00000155.23h24m53.3s_61d34m35sN.FIT                   N/A
# 10      260429_LI_.00000156.23h24m53.3s_61d34m35sN.FIT                   N/A
# 11      260429_LI_.00000157.23h24m54.3s_61d34m35sN.FIT                   N/A
# 12      260429_LI_.00000158.23h24m54.3s_61d34m35sN.FIT                   N/A
# 13      260429_LI_.00000159.23h24m53.3s_61d34m35sN.FIT                   N/A
# 14      260429_LI_.00000160.23h24m53.3s_61d34m35sN.FIT                   N/A
# 15      260429_LI_.00000161.23h24m53.3s_61d34m35sN.FIT                   N/A
# 16      260429_LI_.00000162.23h24m53.3s_61d34m35sN.FIT                   N/A
# 17      260429_LI_.00000163.23h24m53.3s_61d34m35sN.FIT                   N/A
23h24m53.3s_61d34m35sN.BLU...                   N/A
# 68   260429_LI_.00000214.23h24m52.3s_61d34m35sN.BLU...                   N/A
# 69   260429_LI_.00000215.23h24m53.3s_61d34m35sN.BLU...                   N/A
# 70        260429_LI_.00000216.Mouse_click_position.FIT  Mouse_click_position
# 71        260429_LI_.00000217.Mouse_click_position.FIT  Mouse_click_position
# 72   260429_LI_.00000218.Mouse_click_position.LUMIN...  Mouse_click_position
# 73   260429_LI_.00000219.Mouse_click_position.LUMIN...  Mouse_click_position
# 74    260429_LI_.00000220.Mouse_click_position.RED.FIT  Mouse_click_position
# 75    260429_LI_.00000221.Mouse_click_position.RED.FIT  Mouse_click_position
# 76    260429_LI_.00000222.Mouse_click_position.RED.FIT  Mouse_click_position
# 77   260429_LI_.00000223.Mouse_click_position.GREEN...  Mouse_click_position
# 78   260429_LI_.00000224.Mouse_click_position.GREEN...  Mouse_click_position
# 79   260429_LI_.00000225.Mouse_click_position.GREEN...  Mouse_click_position
# 80   260429_LI_.00000226.Mouse_click_position.GREEN...  Mouse_click_position
# 81   260429_LI_.00000227.Mouse_click_position.GREEN...  Mouse_click_position
# 82   260429_LI_.00000228.Mouse_click_position.GREEN...  Mouse_click_position
# 83   260429_LI_.00000229.Mouse_click_position.GREEN...  Mouse_click_position
# 84   260429_LI_.00000230.Mouse_click_position.GREEN...  Mouse_click_position
# 85   260429_LI_.00000231.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 86   260429_LI_.00000232.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 87   260429_LI_.00000233.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 88   260429_LI_.00000234.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 89   260429_LI_.00000235.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 90   260429_LI_.00000236.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 91   260429_LI_.00000237.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 92   260429_LI_.00000238.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 93   260429_LI_.00000239.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 94   260429_LI_.00000240.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 95   260429_LI_.00000241.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 96   260429_LI_.00000242.Mouse_click_position.BLUE.FIT  Mouse_click_position
# 97   260429_LI_.00000243.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 98   260429_LI_.00000244.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 99   260429_LI_.00000245.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 100  260429_LI_.00000246.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 101  260429_LI_.00000247.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 102  260429_LI_.00000248.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 103  260429_LI_.00000249.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 104  260429_LI_.00000250.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 105  260429_LI_.00000251.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 106  260429_LI_.00000252.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 107  260429_LI_.00000253.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 108  260429_LI_.00000254.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 109  260429_LI_.00000255.Mouse_click_position.BIAS.FIT  Mouse_click_position
# 110       260429_LI_.00000257.Mouse_click_position.FIT  Mouse_click_position
# 111       260429_LI_.00000258.Mouse_click_position.FIT  Mouse_click_position
# 112       260429_LI_.00000259.Mouse_click_position.FIT  Mouse_click_position
# 113       260429_LI_.00000260.Mouse_click_position.FIT  Mouse_click_position
# 114       260429_LI_.00000261.Mouse_click_position.FIT  Mouse_click_position
# 115       260429_LI_.00000262.Mouse_click_position.FIT  Mouse_click_position
# 116       260429_LI_.00000263.Mouse_click_position.FIT  Mouse_click_position
# 117       260429_LI_.00000264.Mouse_click_position.FIT  Mouse_click_position
# 118       260429_LI_.00000265.Mouse_click_position.FIT  Mouse_click_position
# 119       260429_LI_.00000266.Mouse_click_position.FIT  Mouse_click_position
# 120                       260429_LI_.00000269.M_52.FIT                  M_52
# 121                       260429_LI_.00000270.M_52.FIT                  M_52
# 122                       260429_LI_.00000271.M_52.FIT                  M_52
# 123                       260429_LI_.00000272.M_52.FIT                  M_52
# 124                       260429_LI_.00000273.M_52.FIT                  M_52
# 125                       260429_LI_.00000274.M_52.FIT                  M_52
# 126                       260429_LI_.00000275.M_52.FIT                  M_52
# 127     260429_LI_.00000276.00h04m59.7s_40d49m25sN.FIT                   N/A
# 128     260429_LI_.00000277.00h05m07.7s_40d49m51sN.FIT                   N/A
# 129     260429_LI_.00000278.00h05m13.7s_40d50m16sN.FIT                   N/A
# 130  260429_LI_.00000279.00h05m13.7s_40d50m16sN.FLA...                   N/A
# 131  260429_LI_.00000280.00h05m18.7s_40d50m42sN.FLA...                   N/A
# 132  260429_LI_.00000281.00h05m27.7s_40d51m08sN.FLA...                   N/A
# 133  260429_LI_.00000282.00h05m27.7s_40d51m08sN.FLA...                   N/A
# 134  260429_LI_.00000283.00h05m30.7s_40d51m34sN.FLA...                   N/A
# 135  260429_LI_.00000284.00h05m41.6s_40d52m00sN.FLA...                   N/A
#
#             type  exptime filter
# 0    Light Frame      5.0      V
# 1    Light Frame      5.0      V
# 2    Light Frame      5.0      B
# 3    Light Frame      5.0      B
# 4    Light Frame      5.0      B
# 5    Light Frame      5.0      V
# 6    Light Frame      5.0      V
# 7    Light Frame      5.0      V
# 8    Light Frame      5.0      V
# 9    Light Frame      5.0      B
# 10   Light Frame      5.0      B
# 11   Light Frame      5.0      B
# 12   Light Frame     60.0      V
# 13   Light Frame     60.0      V
# 14   Light Frame     60.0      B
# 15   Light Frame     60.0      B
# 16   Light Frame     60.0      B
# 17   Light Frame     60.0      B
# 18   Light Frame     60.0      B
# 19   Light Frame     60.0      B
# 20   Light Frame      5.0      V
# 21   Light Frame      5.0      V
# 22   Light Frame      5.0      B
# 23   Light Frame      5.0      B
# 24   Light Frame      5.0      B
# 25   Light Frame     60.0      V
# 26   Light Frame     60.0      V
# 27   Light Frame     60.0      V
# 28   Light Frame     60.0      V
# 29   Light Frame     60.0      V
# 30   Light Frame     60.0      V
# 31   Light Frame     60.0      V
# 32   Light Frame     60.0      V
# 33   Light Frame     60.0      B
# 34   Light Frame     60.0      B
# 35   Light Frame     60.0      B
# 36   Light Frame     60.0      B
# 37   Light Frame     60.0      B
# 38   Light Frame     60.0      B
# 39   Light Frame     60.0      B
# 40   Light Frame     60.0      B
# 41   Light Frame     60.0      B
# 42   Light Frame     60.0      B
# 43   Light Frame     60.0      B
# 44   Light Frame     60.0      B
# 45   Light Frame      5.0      V
# 46   Light Frame      5.0      V
# 47   Light Frame      5.0      B
# 48   Light Frame      5.0      B
# 49   Light Frame      5.0      B
# 50   Light Frame     60.0      V
# 51   Light Frame     60.0      V
# 52   Light Frame     60.0      V
# 53   Light Frame     60.0      V
# 54   Light Frame     60.0      V
# 55   Light Frame     60.0      V
# 56   Light Frame     60.0      V
# 57   Light Frame     60.0      V
# 58   Light Frame     60.0      B
# 59   Light Frame     60.0      B
# 60   Light Frame     60.0      B
# 61   Light Frame     60.0      B
# 62   Light Frame     60.0      B
# 63   Light Frame     60.0      B
# 64   Light Frame     60.0      B
# 65   Light Frame     60.0      B
# 66   Light Frame     60.0      B
# 67   Light Frame     60.0      B
# 68   Light Frame     60.0      B
# 69   Light Frame     60.0      B
# 70   Light Frame     60.0      R
# 71   Light Frame     60.0      R
# 72   Light Frame      5.0      V
# 73   Light Frame      5.0      V
# 74   Light Frame      5.0      B
# 75   Light Frame      5.0      B
# 76   Light Frame      5.0      B
# 77   Light Frame     60.0      V
# 78   Light Frame     60.0      V
# 79   Light Frame     60.0      V
# 80   Light Frame     60.0      V
# 81   Light Frame     60.0      V
# 82   Light Frame     60.0      V
# 83   Light Frame     60.0      V
# 84   Light Frame     60.0      V
# 85   Light Frame     60.0      B
# 86   Light Frame     60.0      B
# 87   Light Frame     60.0      B
# 88   Light Frame     60.0      B
# 89   Light Frame     60.0      B
# 90   Light Frame     60.0      B
# 91   Light Frame     60.0      B
# 92   Light Frame     60.0      B
# 93   Light Frame     60.0      B
# 94   Light Frame     60.0      B
# 95   Light Frame     60.0      B
# 96   Light Frame     60.0      B
# 97    Bias Frame      0.0      R
# 98    Bias Frame      0.0      R
# 99    Bias Frame      0.0      R
# 100   Bias Frame      0.0      R
# 101   Bias Frame      0.0      R
# 102   Bias Frame      0.0      R
# 103   Bias Frame      0.0      R
# 104   Bias Frame      0.0      R
# 105   Bias Frame      0.0      R
# 106   Bias Frame      0.0      R
# 107   Bias Frame      0.0      R
# 108   Bias Frame      0.0      R
# 109   Bias Frame      0.0      R
# 110   Dark Frame      5.0      R
# 111   Dark Frame      5.0      R
# 112   Dark Frame      5.0      R
# 113   Dark Frame      5.0      R
# 114   Dark Frame      5.0      R
# 115   Dark Frame     60.0      R
# 116   Dark Frame     60.0      R
# 117   Dark Frame     60.0      R
# 118   Dark Frame     60.0      R
# 119   Dark Frame     60.0      R
# 120  Light Frame     60.0      R
# 121  Light Frame     60.0      R
# 122  Light Frame     60.0      R
# 123  Light Frame      5.0      R
# 124  Light Frame      5.0      R
# 125  Light Frame      5.0      R
# 126  Light Frame      1.0      R
# 127  Light Frame      1.0      R
# 128  Light Frame      1.0      R
# 129  Light Frame      1.0      R
# 130   Flat Field      1.0      V
# 131   Flat Field      1.0      V
# 132   Flat Field      1.0      V
# 133   Flat Field      1.0      B
# 134   Flat Field      1.0      B
# 135   Flat Field      1.0      B

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

bias_frames = []

print("loading bias frames...")
for idx, row in df.iterrows():
    # check both header type and filename for 'bias'
    if 'BIAS' in str(row['type']).upper() or 'BIAS' in str(row['filename']).upper():
        path = os.path.join(dst, row['filename'])
        try:
            with fits.open(path) as hdul:
                bias_frames.append(hdul[0].data)
        except Exception as e:
            print(f"err loading {row['filename']}: {e}")

# combine to master if we found any
if bias_frames:
    # median combine to kick out cosmic rays / alpha hits
    master_bias = np.median(bias_frames, axis=0)
    print(f"master bias done using {len(bias_frames)} frames.")
    
    # plot with 2-98 percentile scaling to see structures
    plt.figure(figsize=(8, 6))
    plt.imshow(master_bias, cmap='gray', origin='lower', 
               vmin=np.percentile(master_bias, 2), vmax=np.percentile(master_bias, 98))
    plt.colorbar(label='ADU')
    plt.title('Master Bias')
    plt.show()
else:
    print("no bias frames found. check df filtering.")
# Out:
# loading bias frames...
# master bias done using 13 frames.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

dark_frames = []
exposure_time = []
separated_darks = []

print("loading dark frames...")
for idx, row in df.iterrows():
    # check both header type and filename for 'dark'
    if 'DARK' in str(row['type']).upper() or 'DARK' in str(row['filename']).upper():
        path = os.path.join(dst, row['filename'])
        try:
            with fits.open(path) as hdul:
                dark_frames.append(hdul[0].data)
                exposure_time.append(hdul[0].header["EXPTIME"])
        except Exception as e:
            print(f"err loading {row['filename']}: {e}")

            
if dark_frames:
    for idx, i in enumerate(dark_frames):
        separated_darks.append((i - master_bias)/exposure_time[idx])
    master_dark = np.median(separated_darks, axis=0)
    print(f"master dark done using {len(dark_frames)} frames.")
    
    # plot with 2-98 percentile scaling to see structures
    plt.figure(figsize=(8, 6))
    plt.imshow(master_dark, cmap='gray', origin='lower', 
               vmin=np.percentile(master_dark, 2), vmax=np.percentile(master_dark, 98))
    plt.colorbar(label='ADU')
    plt.title('Master dark')
    plt.show()
# Out:
# loading dark frames...
# master dark done using 10 frames.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import fits

# filter flats from main df
flat_df = df[
    (df['filename'].str.contains('FLAT', case=False)) | 
    (df['type'].str.contains('Flat', case=False))
].copy()

# fix missing filters by checking filename strings
for idx, row in flat_df.iterrows():
    if row['filter'] == 'N/A' or pd.isna(row['filter']):
        fname = row['filename'].upper()
        if 'RED' in fname or '_R_' in fname: flat_df.at[idx, 'filter'] = 'R'
        elif 'GREEN' in fname or '_G_' in fname: flat_df.at[idx, 'filter'] = 'G'
        elif 'BLUE' in fname or '_B_' in fname: flat_df.at[idx, 'filter'] = 'B'
        elif 'HA' in fname or 'H_ALPHA' in fname: flat_df.at[idx, 'filter'] = 'H_alpha'
        elif 'LUM' in fname: flat_df.at[idx, 'filter'] = 'Lum'

filters = flat_df['filter'].unique()
print(f"found filters: {filters}")

master_flats = {}

for filt in filters:
    if filt == 'N/A':
        continue
    print(f"\nprocessing filter: {filt}")
    frames = []
    
    filter_df = flat_df[flat_df['filter'] == filt]
    
    for idx, row in filter_df.iterrows():
        path = os.path.join(dst, row['filename'])
        try:
            with fits.open(path) as hdul:
                img_data = hdul[0].data
                exptime = hdul[0].header["EXPTIME"]
                med = np.median(img_data)
                maximum = np.max(img_data)
                
                # quick visual check
                plt.figure(figsize=(4, 3))
                plt.imshow(img_data, cmap='gray', origin='lower', 
                           vmin=np.percentile(img_data, 5), vmax=np.percentile(img_data, 95))
                plt.title(f"{row['filename']}\nMed: {med:.1f} | Max: {maximum}")
                plt.show()
                
                # skip saturated frames (ccd non-linear zone)
                if maximum > 62000:
                    print(f"skipping {row['filename']} -> saturated (max={maximum})")
                    continue
                # skip empty/underexposed frames
                if med < 800:
                    print(f"skipping {row['filename']} -> empty frame (median={med})")
                    continue
                    
                # subtract bias and dark and normalize to 1.0
                bias_sub = img_data - master_bias - (master_dark * exptime)
                norm = bias_sub / np.median(bias_sub)
                frames.append(norm)
                
        except Exception as e:
            print(f"err on {row['filename']}: {e}")
            
    if frames:
        # median combine to get rid of dust/artifacts
        master_flats[filt] = np.median(frames, axis=0)
        print(f"master flat done for filter: {filt}")
        
        # plot normalized flat (should be around 1.0)
        plt.figure(figsize=(6, 5))
        plt.imshow(master_flats[filt], cmap='gray', origin='lower', vmin=0.8, vmax=1.2)
        plt.colorbar()
        plt.title(f'Master Flat - Filter {filt}')
        plt.show()
# Out:
# found filters: ['V' 'B']
#
# processing filter: V
# master flat done for filter: V
# processing filter: B
# master flat done for filter: B

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

print("starting science frame reduction...")

# filter for actual science targets (kick out calibration files)
science_df = df[
    (~df['filename'].str.contains('BIAS|DARK|FLAT|Select|Mouse', case=False)) & 
    (~df['type'].str.contains('Bias|Flat|Dark', case=False))
]

for idx, row in science_df.iterrows():
    f_name = row['filename']
    obj = row['object']
    filt = row['filter']
    
    path = os.path.join(dst, f_name)
    
    # match master flat with current filter
    flat_frame = None
    for k in master_flats.keys():
        if str(k).upper() in str(filt).upper() or str(filt).upper() in str(k).upper():
            flat_frame = master_flats[k]
            break
            
    if flat_frame is None:
        print(f"skipping {f_name}: no master flat found for filter '{filt}'")
        continue
        
    try:
        with fits.open(path) as hdul:
            raw_data = hdul[0].data
            hdr = hdul[0].header
            
            # standard reduction formula: (raw - bias) / flat
            reduced = (raw_data - master_bias) / flat_frame
            
            out_name = "reduced_" + f_name
            out_path = os.path.join(dst, out_name)
            
            # save new fits with original header
            hdu = fits.PrimaryHDU(reduced, header=hdr)
            hdu.writeto(out_path, overwrite=True)
            
            print(f"reduced: {out_name} ({obj} | filter: {filt})")
            
            # plot with 2-98 scaling to check image quality
            plt.figure(figsize=(10, 8))
            vmin = np.percentile(reduced, 2)
            vmax = np.percentile(reduced, 98)
            
            plt.imshow(reduced, cmap='gray', origin='lower', vmin=vmin, vmax=vmax)
            plt.colorbar(label='intensity')
            plt.title(f"Reduced: {obj} | Filter: {filt} ({f_name})")
            plt.show()
            
    except Exception as e:
        print(f"err on reducing {f_name}: {e}")

print("all frames processed. done.")
# Out:
# starting science frame reduction...
# err on reducing 260429_LI_.00000145.23h24m52.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000145.23h24m52.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000146.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000146.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000148.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000148.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000149.23h24m54.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000149.23h24m54.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000150.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000150.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000151.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000151.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000152.23h24m54.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000152.23h24m54.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000153.23h24m52.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000153.23h24m52.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000154.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000154.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000155.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000155.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000156.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000156.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000157.23h24m54.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000157.23h24m54.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000158.23h24m54.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000158.23h24m54.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000159.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000159.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000160.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000160.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000161.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000161.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000162.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000162.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000163.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000163.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000164.23h24m54.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000164.23h24m54.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000165.23h24m53.3s_61d34m35sN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000165.23h24m53.3s_61d34m35sN.FIT'
# err on reducing 260429_LI_.00000166.23h24m53.3s_61d34m35sN.LUMINANCE.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000166.23h24m53.3s_61d34m35sN.LUMINANCE.FIT'
# err on reducing 260429_LI_.00000167.23h24m54.3s_61d34m35sN.LUMINANCE.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000167.23h24m54.3s_61d34m35sN.LUMINANCE.FIT'
# err on reducing 260429_LI_.00000168.23h24m53.3s_61d34m35sN.RED.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000168.23h24m53.3s_61d34m35sN.RED.FIT'
# err on reducing 260429_LI_.00000169.23h24m53.3s_61d34m35sN.RED.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000169.23h24m53.3s_61d34m35sN.RED.FIT'
# err on reducing 260429_LI_.00000170.23h24m54.3s_61d34m35sN.RED.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000170.23h24m54.3s_61d34m35sN.RED.FIT'
# err on reducing 260429_LI_.00000171.23h24m53.3s_61d34m35sN.GREEN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000171.23h24m53.3s_61d34m35sN.GREEN.FIT'
# err on reducing 260429_LI_.00000172.23h24m53.3s_61d34m35sN.GREEN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000172.23h24m53.3s_61d34m35sN.GREEN.FIT'
# err on reducing 260429_LI_.00000173.23h24m54.3s_61d34m35sN.GREEN.FIT: [Errno 13] Permission denied: '/net/virgo01/data/users/ahayr/meine_beobachtungen/reduced_260429_LI_.00000173.23h24m54.3s_61d34m35sN.GREEN.FIT'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 34
#      32 try:
#      33     with fits.open(path) as hdul:
# ---> 34         raw_data = hdul[0].data
#      35         hdr = hdul[0].header
#      37         # standard reduction formula: (raw - bias) / flat
#
# File /Software/users/modules/9/software/anaconda3/2023.03/lib/python3.10/site-packages/astropy/utils/decorators.py:837, in lazyproperty.__get__(self, obj, owner)
#     835         val = obj_dict.get(self._key, _NotFound)
#     836         if val is _NotFound:
# --> 837             val = self.fget(obj)
#     838             obj_dict[self._key] = val
#     839 return val
#
# File /Software/users/modules/9/software/anaconda3/2023.03/lib/python3.10/site-packages/astropy/io/fits/hdu/image.py:250, in _ImageBaseHDU.data(self)
#     247 if len(self._axes) < 1:
#     248     return
# --> 250 data = self._get_scaled_image_data(self._data_offset, self.shape)
#     251 self._update_header_scale_info(data.dtype)
#     253 return data
#
# File /Software/users/modules/9/software/anaconda3/2023.03/lib/python3.10/site-packages/astropy/io/fits/hdu/image.py:830, in _ImageBaseHDU._get_scaled_image_data(self, offset, shape)
#     828 data = None
#     829 if not (self._orig_bzero == 0 and self._orig_bscale == 1):
# --> 830     data = self._convert_pseudo_integer(raw_data)
#     832 if data is None:
#     833     # In these cases, we end up with floating-point arrays and have to
#     834     # apply bscale and bzero. We may have to handle BLANK and convert
#     835     # to NaN in the resulting floating-point arrays.
#     836     # The BLANK keyword should only be applied for integer data (this
#     837     # is checked in __init__ but it can't hurt to double check here)
#     838     blanks = None
#
# File /Software/users/modules/9/software/anaconda3/2023.03/lib/python3.10/site-packages/astropy/io/fits/hdu/image.py:796, in _ImageBaseHDU._convert_pseudo_integer(self, data)
#     790 if dtype is not None and dtype.kind == "u":
#     791     # Convert the input raw data into an unsigned integer array and
#     792     # then scale the data adjusting for the value of BZERO.  Note that
#     793     # we subtract the value of BZERO instead of adding because of the
#     794     # way numpy converts the raw signed array into an unsigned array.
#     795     bits = dtype.itemsize * 8
# --> 796     data = np.array(data, dtype=dtype)
#     797     data -= np.uint64(1 << (bits - 1))
#     799     return data
#
# KeyboardInterrupt:
